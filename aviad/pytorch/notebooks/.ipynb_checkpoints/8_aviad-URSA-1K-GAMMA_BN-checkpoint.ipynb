# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
import scipy as sp
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
import seaborn as sns

from collections import defaultdict
from itertools import groupby
from sklearn import datasets
from numpy import random
from scipy.stats import dirichlet, norm, poisson

# %%
# from keras.datasets import reuters, imdb

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset

# %%
import numpy as np
import os

# %%
from pathlib import Path
from collections import OrderedDict
import pickle, gzip, math, torch, matplotlib as mpl
import matplotlib.pyplot as plt

Path.ls = lambda x: list(x.iterdir())

# %% [markdown]
# ## URSA Datasets 1K

# %%
folder_ds_path = Path('../data/User Review Structure Analysis (URSA)/')
xml_path = (folder_ds_path/'Classified_Corpus.xml')
ds_path = (folder_ds_path/'1k')
sentence_npy_path = (folder_ds_path/'sentence.npy')
vocab_pkl_path = (ds_path/'vocab.pkl')
seed_words_path = (ds_path/'seed_words.txt')
train_filename = (ds_path/'train.txt.npy')

# log words not pass
aspect_tags = ['Food', 'Staff', 'Ambience']
polatiry_tags = ['Positive', 'Negative', 'Neutral']
xml_review_tag = './/Review'
log_np = [[], [], []]

# length allowed sentences
# length_allowed = [11, 7, 4]
# min_freq_allowed = -1

# %%
vocab2id = pickle.load(open(vocab_pkl_path, 'rb'))
vocab_size=len(vocab2id)

# %%
train_data = np.load((train_filename), allow_pickle=True)

# %%
p_sentence_list, label_list = train_data[:, 0], train_data[:, 1]

# %%
vocab = dict(map(reversed, vocab2id.items()))

# %%
vocab_size = len(vocab)

# %% [markdown]
# ## Dataset

# %%
from sklearn.model_selection import train_test_split

# %%
x_, y_ = [], []
for p_sentence, label_ in zip(p_sentence_list, label_list): 
    x_.append(p_sentence)
    y_.append(label_)

# %%
len(x_) == len(y_)
# Out:
# True

# %%
train_x, test_x, train_y, test_y =  train_test_split(
    x_, y_, test_size=0.1, random_state=0)

# %%
print ('Data Loaded')
print ('Dim Training Data',len(train_x), vocab_size)
print ('Dim Test Data', len(test_x), vocab_size)
# Out:
# Data Loaded
# Dim Training Data 3095 2772
# Dim Test Data 344 2772

# %% [markdown]
# ## Constants

# %%
bs = 200
en1_units=100
en2_units=100
num_topic=3
num_input=vocab_size
variance=0.995
init_mult=1.0
learning_rate=0.0005
batch_size=200
momentum=0.99
num_epoch=200
nogpu=True
drop_rate=0.6

# %% [markdown]
# ## Topic Model Utility Functions

# %%
def read_file_seed_words(fn):
    with open(fn, "r") as fr:
        def p_string_sw(l):
            return l.replace('\n','').split(',')
        rl = [p_string_sw(l) for l in fr]
    return rl

# %% [markdown]
# ## Seed words

# %%
seed_words = read_file_seed_words(seed_words_path)

# %%
print (seed_words)
# Out:
# [['food', 'sauc', 'chicken', 'shrimp', 'chees', 'potato', 'fri', 'tomato', 'roast', 'onion', 'pork', 'goat', 'grill', 'tuna', 'salad', 'beef', 'tapa'], ['staff', 'servic', 'friendli', 'rude', 'hostess', 'waiter', 'bartend', 'waitress', 'help', 'polit', 'bar', 'courteou', 'member', 'waitstaff', 'attitud', 'reserv', 'tip'], ['atmospher', 'scene', 'place', 'tabl', 'outsid', 'area', 'ambianc', 'outdoor', 'romant', 'cozi', 'decor', 'sit', 'wall', 'light', 'window', 'area', 'ceil', 'floor']]

# %%
def setup_prior(fn, n_k=3):
    gamma = torch.zeros((len(vocab),n_k))
    gamma_bin = torch.zeros((1, len(vocab),n_k))

    full_vocab = read_file_seed_words(fn)
    for k in range(len(full_vocab)):
        for idx in range(len(full_vocab[k])):
            ivocab = vocab2id[full_vocab[k][idx]]
            gamma[ivocab, k] = 1.0
            gamma_bin[:, ivocab, :] = 1.0

    return (gamma, gamma_bin)

# %%
def listify(o):
    if o is None: return []
    if isinstance(o, list): return o
    if isinstance(o, str): return [o]
    if isinstance(o, Iterable): return list(o)
    return [o]
def setify(o): return o if isinstance(o,set) else set(listify(o))
def compose(x, funcs, *args, order_key='_order', **kwargs):
    key = lambda o: getattr(o, order_key, 0)
    for f in sorted(listify(funcs), key=key): x = f(x, **kwargs)
    return x

# %%
def print_perp(model):
    cost = []
    model.eval()                        # switch to testing mode
    for x_test, y_test in test_dl:
        recon, loss = model(x_test, compute_loss=True, avg_loss=False)
        loss = loss.data
        counts = x_test.sum(1)
        cost.extend((loss / counts).data.cpu().tolist())
    print('The approximated perplexity is: ', (np.exp(np.mean(np.array(cost)))))

def print_top_words(beta, feature_names, n_top_words=10):
    print ('---------------Printing the Topics------------------')
    for i in range(len(beta)):
        line = " ".join([feature_names[j] 
                         for j in beta[i].argsort()[:-n_top_words - 1:-1]])
        print('{}'.format(line))
    print ('---------------End of Topics------------------')
    
def print_gamma(gamma, seed_words, vocab, vocab2id):
    sws = []        
    for k in range(len(seed_words)):
        for idx in range(len(seed_words[k])):
            w = seed_words[k][idx]
            sws.append((k, w))

    for idx in range(len(sws)):
        k, w = sws[idx]
        ivocab = vocab2id[w]
        mk = gamma[ivocab].argmax(-1)
        print (ivocab, w, k, mk, gamma[ivocab])

# %% [markdown]
# ## Data Utility Functions

# %%
def collate(b):
    x, y = zip(*b)
    return torch.stack(x), torch.stack(y)

class IdifyAndLimitedVocab():
    _order=-1
    def __init__(self, vocab2id, limited_vocab):
        self.vocab2id = vocab2id
        self.limited_vocab = limited_vocab
    def __call__(self, item):
        idlist = [self.vocab2id[w] for w in item if self.vocab2id[w] < self.limited_vocab]
        return np.array(idlist)
    

class Numpyify():
    _order=0
    def __call__(self, item):
        return np.array(item)

class Onehotify():
    _order=1
    def __init__(self, vocab_size):
        self.vocab_size = vocab_size
    def __call__(self, item):
        return np.array(np.bincount(item.astype('int'), minlength=self.vocab_size))
    
class YToOnehot():
    _order=1
    def __init__(self, num_classes):
        self.num_classes = num_classes
    def __call__(self, item):
        categorical = np.zeros((1, self.num_classes))
        categorical[0, item] = 1
        return categorical

class Tensorify():
    _order=2
    def __call__(self, item):
        return torch.from_numpy(item)

class Floatify():
    _order=3
    def __call__(self, item):
        return item.float()
    
class CheckAndCudify():
    _order=100
    def __init__(self):
        self.ic = torch.cuda.is_available()
    def __call__(self, item):
        return item.cuda() if self.ic else item
    
class URSADataset(Dataset):
    def __init__(self, x, y, tfms_x, tfms_y): 
        self.x, self.y = x, y
        self.x_tfms = tfms_x
        self.y_tfms = tfms_y
    def __len__(self): 
        return len(self.x)
    def __getitem__(self, i): 
        return compose(self.x[i], self.x_tfms), compose(self.y[i], self.y_tfms)
    
class Sampler():
    def __init__(self, ds, bs, shuffle=False):
        self.n,self.bs,self.shuffle = len(ds),bs,shuffle
        
    def __iter__(self):
        self.idxs = torch.randperm(self.n) if self.shuffle else torch.arange(self.n)
        for i in range(0, self.n, self.bs): yield self.idxs[i:i+self.bs]

class DataLoader():
    def __init__(self, ds, sampler, collate_fn=collate):
        self.ds,self.sampler,self.collate_fn = ds,sampler,collate_fn
        
    def __iter__(self):
        for s in self.sampler: yield self.collate_fn([self.ds[i] for i in s])

# %% [markdown]
# ## Load Data

# %%
num_classes = np.max(train_y) + 1

# %%
num_classes
# Out:
# 3

# %%
tfms_x = [Numpyify(), Onehotify(vocab_size=vocab_size), Tensorify(), Floatify(), CheckAndCudify()]
tfms_y = [YToOnehot(num_classes=num_classes), Tensorify(), Floatify(), CheckAndCudify()]

# %%
train_ds = URSADataset(train_x, train_y, tfms_x=tfms_x, tfms_y=tfms_y)
test_ds = URSADataset(test_x, test_y, tfms_x=tfms_x, tfms_y=tfms_y)

# %%
train_samp = Sampler(train_ds, bs, shuffle=False)
test_samp = Sampler(test_ds, bs, shuffle=False)

# %%
train_dl = DataLoader(train_ds, sampler=train_samp, collate_fn=collate)
test_dl = DataLoader(test_ds, sampler=test_samp, collate_fn=collate)

# %%
gamma_prior = setup_prior(seed_words_path, 3)

# %%
gamma, gamma_bin = gamma_prior

# %% [markdown]
# ## Define Model

# %%
class ProdLDA(nn.Module):
    def __init__(self, num_input, en1_units, en2_units, num_topic, drop_rate, init_mult, gamma_prior):
        super(ProdLDA, self).__init__()
        self.num_input, self.en1_units, self.en2_units, \
        self.num_topic, self.drop_rate, self.init_mult = num_input, en1_units, en2_units, \
                                                            num_topic, drop_rate, init_mult
        # gamma prior
        self.gamma_prior = gamma_prior
        
        # encoder
        self.en1_fc = nn.Linear(num_input, en1_units)
        self.en1_ac = nn.Softplus()
        self.en2_fc     = nn.Linear(en1_units, en2_units)
        self.en2_ac = nn.Softplus()
        self.en2_dr   = nn.Dropout(drop_rate)
        
        # mean, logvar
        self.mean_fc = nn.Linear(en2_units, num_topic)
        self.mean_bn = nn.BatchNorm1d(num_topic)
        self.logvar_fc = nn.Linear(en2_units, num_topic)
        self.logvar_bn = nn.BatchNorm1d(num_topic)

        # decoder
        self.de_ac1 = nn.Softmax(dim=-1)
        self.de_dr = nn.Dropout(drop_rate)
        self.de_fc = nn.Linear(num_topic, num_input)
        self.de_bn = nn.BatchNorm1d(num_input)
        self.de_ac2 = nn.Softmax(dim=-1)
        
        # prior mean and variance as constant buffers
        self.prior_mean   = torch.Tensor(1, num_topic).fill_(0)
        self.prior_var    = torch.Tensor(1, num_topic).fill_(variance)
        self.prior_mean   = nn.Parameter(self.prior_mean, requires_grad=False)
        self.prior_var    = nn.Parameter(self.prior_var, requires_grad=False)
        self.prior_logvar = nn.Parameter(self.prior_var.log(), requires_grad=False)
        # initialize decoder weight
        if init_mult != 0:
            #std = 1. / math.sqrt( init_mult * (num_topic + num_input))
            self.de_fc.weight.data.uniform_(0, init_mult)
        # remove BN's scale parameters
        for component in [self.mean_bn, self.logvar_bn, self.de_bn]:
            component.weight.requires_grad = False
            component.weight.fill_(1.0)
        
    def gamma(self):
        # this function have to run after self.encode
        encoder_w1 = self.en1_fc.weight
        encoder_b1 = self.en1_fc.bias
        encoder_w2 = self.en2_fc.weight
        encoder_b2 = self.en2_fc.bias
        mean_w = self.mean_fc.weight
        mean_b = self.mean_fc.bias
        mean_running_mean = self.mean_bn.running_mean
        mean_running_var = self.mean_bn.running_var
        logvar_w = self.logvar_fc.weight
        logvar_b = self.logvar_fc.bias
        logvar_running_mean = self.logvar_bn.running_mean
        logvar_running_var = self.logvar_bn.running_var
        
        w1 = F.softplus(encoder_w1.t() + encoder_b1)
        w2 = F.softplus(F.linear(w1, encoder_w2, encoder_b2))
        wdr = F.dropout(w2, self.drop_rate)
        wo_mean = F.softmax(F.batch_norm(F.linear(wdr, mean_w, mean_b), mean_running_mean, mean_running_var), dim=-1)
        wo_logvar = F.softmax(F.batch_norm(F.linear(wdr, logvar_w, logvar_b), logvar_running_mean, logvar_running_var), dim=-1)
        
        return wo_mean, wo_logvar
            
    def encode(self, input_):
        # encoder
        encoded1 = self.en1_fc(input_)
        encoded1_ac = self.en1_ac(encoded1)
        encoded2 = self.en2_fc(encoded1_ac)
        encoded2_ac = self.en2_ac(encoded2)
        encoded2_dr = self.en2_dr(encoded2_ac)
        
        encoded = encoded2_dr
        
        # hidden => mean, logvar
        mean_theta = self.mean_fc(encoded)
        mean_theta_bn = self.mean_bn(mean_theta)
        logvar_theta = self.logvar_fc(encoded)
        logvar_theta_bn = self.logvar_bn(logvar_theta)
        
        posterior_mean = mean_theta_bn
        posterior_logvar = logvar_theta_bn
        return encoded, posterior_mean, posterior_logvar
    
    def decode(self, input_, posterior_mean, posterior_var):
        # take sample
        eps = input_.data.new().resize_as_(posterior_mean.data).normal_() # noise 
        z = posterior_mean + posterior_var.sqrt() * eps                   # reparameterization
        # do reconstruction
        # decoder
        decoded1_ac = self.de_ac1(z)
        decoded1_dr = self.de_dr(decoded1_ac)
        decoded2 = self.de_fc(decoded1_dr)
        decoded2_bn = self.de_bn(decoded2)
        decoded2_ac = self.de_ac2(decoded2_bn)
        recon = decoded2_ac          # reconstructed distribution over vocabulary
        return recon
    
    def forward(self, input_, compute_loss=False, avg_loss=True):
        # compute posterior
        en2, posterior_mean, posterior_logvar = self.encode(input_) 
        posterior_var    = posterior_logvar.exp()
        
        recon = self.decode(input_, posterior_mean, posterior_var)
        if compute_loss:
            return recon, self.loss(input_, recon, posterior_mean, posterior_logvar, posterior_var, avg_loss)
        else:
            return recon

    def loss(self, input_, recon, posterior_mean, posterior_logvar, posterior_var, avg=True):
        # NL
        NL  = -(input_ * (recon + 1e-10).log()).sum(1)
        # KLD, see Section 3.3 of Akash Srivastava and Charles Sutton, 2017, 
        # https://arxiv.org/pdf/1703.01488.pdf
        prior_mean   = self.prior_mean.expand_as(posterior_mean)
        prior_var    = self.prior_var.expand_as(posterior_mean)
        prior_logvar = self.prior_logvar.expand_as(posterior_mean)
        var_division    = posterior_var  / prior_var
        diff            = posterior_mean - prior_mean
        diff_term       = diff * diff / prior_var
        logvar_division = prior_logvar - posterior_logvar
        # put KLD together
        KLD = 0.5 * ( (var_division + diff_term + logvar_division).sum(1) - self.num_topic)
        
        # gamma
        n, _ = input_.size()
        gamma_mean, gamma_logvar = self.gamma()
        gamma_prior, gammar_prior_bin = self.gamma_prior
        input_t = (input_ > 0).unsqueeze(dim=-1)
        input_bin = ((gammar_prior_bin.expand(n, -1, -1) == 1) & input_t)
        lambda_c = 20.0
        
        gamma_prior = gamma_prior.expand(n, -1, -1)      
        
        GL = lambda_c * ((gamma_prior - (input_bin.int()*gamma_mean))**2).sum((1, 2))
        
        # loss
        loss = (NL + KLD + GL)
        
        # in traiming mode, return averaged loss. In testing mode, return individual loss
        if avg:
            return loss.mean()
        else:
            return loss

# %% [markdown]
# ## Train

# %%
from sklearn import metrics

# %%
def compute_accuracy(y_pred, y_true):
    accuracy = metrics.accuracy_score(y_true, y_pred)
    precision, recall, f1_score, _ = metrics.precision_recall_fscore_support(y_true=y_true, \
                                                     y_pred=y_pred, \
                                                     average=None)

    return (accuracy, precision, recall, f1_score)

# %%
model = ProdLDA(num_input, en1_units, en2_units, num_topic, drop_rate, init_mult, gamma_prior)
optimizer = torch.optim.Adam(model.parameters(), learning_rate, betas=(momentum, 0.999))

# %%
if torch.cuda.is_available():
    model = model.cuda()

# %%
for epoch in range(num_epoch):
    loss_epoch = 0.0
    model.train()                    # switch to training mode
    for input_, label_ in train_dl:
        recon, loss = model(input_, compute_loss=True)
        # optimize
        optimizer.zero_grad()        # clear previous gradients
        loss.backward()              # backprop
        optimizer.step()             # update parameters
        # report
        loss_epoch += loss.item()    # add loss to loss_epoch
    if (epoch + 1) % 10 == 0:
        model.eval()
        # Test Model
        pred_train = []
        label_train = []
        pred_test = []
        label_test = []
        
        for x_train, y_train in train_dl:
            encoded, theta_mean, theta_logvar = model.encode(x_train)
            temp_theta_mean = theta_mean.argmax(-1).int().data.cpu().tolist()
            temp_y_train = y_train.argmax(-1).flatten().data.cpu().tolist()
            
            pred_train.extend(temp_theta_mean)
            label_train.extend(temp_y_train)
        
        accuracy_train, precision_train, recall_train, f1_score_train = compute_accuracy(pred_train, label_train)
        
        for x_test, y_test in test_dl:
            encoded, theta_mean, theta_logvar = model.encode(x_test)
            temp_theta_mean = theta_mean.argmax(-1).int().data.cpu().tolist()
            temp_y_test = y_test.argmax(-1).flatten().data.cpu().tolist()
            
            pred_test.extend(temp_theta_mean)
            label_test.extend(temp_y_test)
        
        accuracy_test, precision_test, recall_test, f1_score_test = compute_accuracy(pred_test, label_test)
        print ("##################################################")
        print('Epoch {}, loss={}, accuracy_train={}, accuracy_test={}'.format(epoch, loss_epoch / len(input_), accuracy_train, accuracy_test))
        for k in range(num_topic):
            print ("precision_train{}".format(k), "=" , "{:.9f}".format(precision_train[k]), \
                 "recall_train{}".format(k), "=" , "{:.9f}".format(recall_train[k]), \
                 "f1_score_train{}".format(k), "=" , "{:.9f}".format(f1_score_train[k]))
            print ("precision_te{}".format(k), "=" , "{:.9f}".format(precision_test[k]), \
                 "recall_te{}".format(k), "=" , "{:.9f}".format(recall_test[k]), \
                 "f1_score_te{}".format(k), "=" , "{:.9f}".format(f1_score_test[k]))
        emb = model.de_fc.weight.data.detach().cpu().numpy().T
        print_top_words(emb, vocab, 50)
        print_perp(model)
        print ("##################################################")
# Out:
# /home/huylb314/anaconda3/envs/avi/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1268: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ##################################################
# Epoch 0, loss=199.263525390625, accuracy_train=0.3431340872374798, accuracy_test=0.3546511627906977
# precision_train0 = 0.342820181 recall_train0 = 1.000000000 f1_score_train0 = 0.510597303
# precision_te0 = 0.354651163 recall_te0 = 1.000000000 f1_score_te0 = 0.523605150
# precision_train1 = 0.000000000 recall_train1 = 0.000000000 f1_score_train1 = 0.000000000
# precision_te1 = 0.000000000 recall_te1 = 0.000000000 f1_score_te1 = 0.000000000
# precision_train2 = 0.666666667 recall_train2 = 0.002096436 f1_score_train2 = 0.004179728
# precision_te2 = 0.000000000 recall_te2 = 0.000000000 f1_score_te2 = 0.000000000
# ---------------Printing the Topics------------------
# scallop itali ginger gem becom whole drop ala importantli villag trulli worth dig chain dip connoisseur profession popular inde vinyl contribut ice someon moist mall gossip dynamit carb chandeli radish stand spend peanut volum calm kitsch cucumb taco broadway member wont greasi clueless care rum imposs pace wipe rich crabcak
# soar n abund respons stain groovi compar life anywher patient balsam quirki tequila late sliver chicken sichuan mediocr brioch act ned kobe broad inspir neither hip feta ex dot tier age charg prior song appeal trulli loaf maki e success pollo linen smith either stupid spread citru dinner point squid
# someth host mignon mint butter nowher brown serv provid chines shame memor true roe fold mere stuck gossip older melon second hearti kept almond exist rack yorker beat silver buttermilk deliv wors children stylish contain discuss frame promis fix ear background max soho monkfish bombay drawback veal embarrass confirm quett
# ---------------End of Topics------------------
# The approximated perplexity is:  4.090483119890957e+25
# ##################################################
# ##################################################
# Epoch 5, loss=199.3436189350329, accuracy_train=0.4378029079159935, accuracy_test=0.4069767441860465
# precision_train0 = 0.847058824 recall_train0 = 0.407547170 f1_score_train0 = 0.550318471
# precision_te0 = 0.890909091 recall_te0 = 0.401639344 f1_score_te0 = 0.553672316
# precision_train1 = 0.250000000 recall_train1 = 0.010175763 f1_score_train1 = 0.019555556
# precision_te1 = 0.250000000 recall_te1 = 0.024193548 f1_score_te1 = 0.044117647
# precision_train2 = 0.358913813 recall_train2 = 0.955974843 f1_score_train2 = 0.521888412
# precision_te2 = 0.317689531 recall_te2 = 0.897959184 f1_score_te2 = 0.469333333
# ---------------Printing the Topics------------------
# itali scallop trulli villag whole becom worth spend ginger gem ala importantli taco ice chain profession drop carb gossip care broadway someon dip stand chandeli eel calm hour either greasi rich popular around drape volum chair peanut contribut cucumb deco style dig radish moist abl inattent ass beauti banana connoisseur
# n stain mediocr chicken sliver inspir soar sichuan kobe life charg either anywher e tier respons late patient hip citru groovi spread soundtrack chopstick terribl abund machin trulli pollo roast act dinner compar age song date paella point loaf neither bill mismatch magnifico feel success balsam dot maki spill smith
# someth host gossip children butter chines stuck serv exist mint roe filet fix fold hearti stylish brown second lit true silver nowher mignon yorker provid kept draw shame soho melon almond tang deliv atmospher wors background embarrass confirm red gra india rack sticki beat might privat bombay mismatch max veal
# ---------------End of Topics------------------
# The approximated perplexity is:  4.388465987614968e+25
# ##################################################
# ##################################################
# Epoch 10, loss=199.07673596833882, accuracy_train=0.6594507269789984, accuracy_test=0.627906976744186
# precision_train0 = 0.670936749 recall_train0 = 0.790566038 f1_score_train0 = 0.725855349
# precision_te0 = 0.688405797 recall_te0 = 0.778688525 f1_score_te0 = 0.730769231
# precision_train1 = 0.822878229 recall_train1 = 0.412580944 f1_score_train1 = 0.549599507
# precision_te1 = 0.770491803 recall_te1 = 0.379032258 f1_score_te1 = 0.508108108
# precision_train2 = 0.580521472 recall_train2 = 0.793501048 f1_score_train2 = 0.670504872
# precision_te2 = 0.510344828 recall_te2 = 0.755102041 f1_score_te2 = 0.609053498
# ---------------Printing the Topics------------------
# itali scallop trulli becom villag whole spend worth eel rich either care hour broadway ice around taco chair drop chandeli gem ginger style drape gossip chain profession stand carb greasi nut abl beauti inattent calm someon ala chines banana importantli deco great dip sausag radish job peanut volum interior cucumb
# n mediocr stain inspir sichuan sliver kobe e chicken either charg tier soar spread hip soundtrack respons terribl life anywher machin citru patient chopstick java trulli roast pollo spill paella late mismatch dinner sincer district feel magnifico cater date age bill relish loaf away dark success effici smoke act point
# someth gossip chines host children exist butter serv filet stuck fix mint stylish roe lit hearti silver fold kept atmospher red intend tang brown bakeri draw midtown second limit true might yorker dark great mignon soho hard gra mismatch roast melon provid spread nowher sticki embarrass almond background confirm inch
# ---------------End of Topics------------------
# The approximated perplexity is:  4.069736294050738e+25
# ##################################################
# ##################################################
# Epoch 15, loss=198.2939144736842, accuracy_train=0.6636510500807754, accuracy_test=0.6308139534883721
# precision_train0 = 0.720113852 recall_train0 = 0.716037736 f1_score_train0 = 0.718070009
# precision_te0 = 0.780952381 recall_te0 = 0.672131148 f1_score_te0 = 0.722466960
# precision_train1 = 0.819466248 recall_train1 = 0.482886216 f1_score_train1 = 0.607683353
# precision_te1 = 0.770270270 recall_te1 = 0.459677419 f1_score_te1 = 0.575757576
# precision_train2 = 0.550569801 recall_train2 = 0.810272537 f1_score_train2 = 0.655640373
# precision_te2 = 0.472727273 recall_te2 = 0.795918367 f1_score_te2 = 0.593155894
# ---------------Printing the Topics------------------
# itali scallop trulli eel becom rich either villag hour whole around chair care spend style worth drop ice chines sausag chandeli nut great broadway abl taco gossip beauti drape hearti gem chain banana carb stand greasi ultim deco interior inattent radish profession someon calm pineappl ginger root job waitress area
# n mediocr inspir e sichuan stain either charg sliver kobe chicken spread java terribl tier soundtrack hip respons soar spill trulli cater district life pollo sincer roast citru machin patient away magnifico chopstick feel mismatch paella anywher effici date dark dinner bill age smooth loaf late smoke band relish even
# someth gossip children chines host exist serv filet butter stuck lit stylish fix mint silver bakeri midtown roe intend dark red kept tang hearti limit fold atmospher great might roast draw hard feel mismatch spread brown gra list embarrass true yorker soho can second sticki citru sliver inch shini ultim
# ---------------End of Topics------------------
# The approximated perplexity is:  3.6833778915075606e+25
# ##################################################
# ##################################################
# Epoch 20, loss=197.9882504111842, accuracy_train=0.6869143780290792, accuracy_test=0.6744186046511628
# precision_train0 = 0.703735882 recall_train0 = 0.764150943 f1_score_train0 = 0.732700136
# precision_te0 = 0.744000000 recall_te0 = 0.762295082 f1_score_te0 = 0.753036437
# precision_train1 = 0.786821705 recall_train1 = 0.563367253 f1_score_train1 = 0.656603774
# precision_te1 = 0.766666667 recall_te1 = 0.556451613 f1_score_te1 = 0.644859813
# precision_train2 = 0.604273504 recall_train2 = 0.741090147 f1_score_train2 = 0.665725047
# precision_te2 = 0.542635659 recall_te2 = 0.714285714 f1_score_te2 = 0.616740088
# ---------------Printing the Topics------------------
# itali scallop eel trulli either rich sausag hour becom great hearti around chair villag style whole chines nut drop worth care beauti broadway abl chandeli pineappl ice spend taco drape ultim gossip banana greasi interior peke tender radish chain stand sometim waitress egg carb soundtrack children gem deco inattent root
# n e mediocr inspir java either sichuan stain charg sliver terribl kobe hip spread chicken soundtrack tier cater away spill respons effici pollo smooth district sincer feel soar patient magnifico trulli roast citru machin paella mismatch chopstick even dark date life age loaf bill dinner band smoke anywher mod environ
# someth children chines gossip serv filet exist host lit butter stuck bakeri dark stylish midtown silver fix red intend mint feel might tang kept great atmospher roe limit fold hard roast spread citru mismatch hearti list draw sliver gra ultim embarrass sometim inch brown can machin patron shini soho yorker
# ---------------End of Topics------------------
# The approximated perplexity is:  2.928589913761815e+25
# ##################################################
# ##################################################
# Epoch 25, loss=197.63344341077303, accuracy_train=0.6995153473344103, accuracy_test=0.6976744186046512
# precision_train0 = 0.723253758 recall_train0 = 0.771698113 f1_score_train0 = 0.746691009
# precision_te0 = 0.744000000 recall_te0 = 0.762295082 f1_score_te0 = 0.753036437
# precision_train1 = 0.736842105 recall_train1 = 0.647548566 f1_score_train1 = 0.689315608
# precision_te1 = 0.733944954 recall_te1 = 0.645161290 f1_score_te1 = 0.686695279
# precision_train2 = 0.638067061 recall_train2 = 0.678197065 f1_score_train2 = 0.657520325
# precision_te2 = 0.609090909 recall_te2 = 0.683673469 f1_score_te2 = 0.644230769
# ---------------Printing the Topics------------------
# itali scallop eel sausag either great trulli hearti rich style chines around hour pineappl becom chair nut villag worth peke tender abl whole care drop beauti sometim egg broadway ultim chandeli taco ice drape greasi gossip soundtrack radish stand boyfriend banana waitress forev filet interior spend chain job root carb
# n java e mediocr either inspir charg sichuan terribl stain hip away smooth cater sliver kobe spread soundtrack tier effici sincer chicken patient spill feel even respons pollo district soar citru age magnifico date trulli roast paella dark machin chopstick loaf mismatch bill band move mod kielbasa home environ dinner
# children someth chines gossip serv lit filet host exist dark bakeri butter midtown feel stuck stylish fix might silver intend red atmospher citru limit mint tang great sliver spread kept mismatch fold list hard roast roe ultim inch gra hearti patron draw machin shini sometim embarrass kielbasa can pearl brown
# ---------------End of Topics------------------
# The approximated perplexity is:  2.732795566012371e+25
# ##################################################
# ##################################################
# Epoch 30, loss=197.2058375308388, accuracy_train=0.7082390953150243, accuracy_test=0.7063953488372093
# precision_train0 = 0.718512257 recall_train0 = 0.801886792 f1_score_train0 = 0.757913509
# precision_te0 = 0.734848485 recall_te0 = 0.795081967 f1_score_te0 = 0.763779528
# precision_train1 = 0.721200387 recall_train1 = 0.689176688 f1_score_train1 = 0.704824976
# precision_te1 = 0.720338983 recall_te1 = 0.685483871 f1_score_te1 = 0.702479339
# precision_train2 = 0.679180887 recall_train2 = 0.625786164 f1_score_train2 = 0.651391162
# precision_te2 = 0.648936170 recall_te2 = 0.622448980 f1_score_te2 = 0.635416667
# ---------------Printing the Topics------------------
# scallop sausag itali great either eel hearti rich trulli style pineappl tender chines peke nut around egg hour worth sometim abl becom care villag chair beauti ultim soundtrack taco boyfriend greasi filet broadway ice drop whole stand forev banana chandeli share gossip drape loaf root radish interior waitress free children
# n java e mediocr smooth either terribl away charg inspir hip sichuan stain cater even effici kobe spread sliver age tier soundtrack sincer patient spill respons date feel citru soar district waitress pollo magnifico trulli move dark paella band mismatch chopstick machin roast loaf chicken bill mod home kielbasa pineappl
# children someth chines lit serv dark gossip feel bakeri filet exist host midtown butter stylish might stuck atmospher citru silver fix intend sliver limit red mismatch spread fold tang great mint kept list hard ultim inch gra patron hearti machin roe shini sometim roast draw environ embarrass kielbasa weather yorker
# ---------------End of Topics------------------
# The approximated perplexity is:  2.3468429584836523e+25
# ##################################################
# ##################################################
# Epoch 35, loss=196.44678376850328, accuracy_train=0.7305331179321486, accuracy_test=0.7441860465116279
# precision_train0 = 0.745674740 recall_train0 = 0.813207547 f1_score_train0 = 0.777978339
# precision_te0 = 0.775193798 recall_te0 = 0.819672131 f1_score_te0 = 0.796812749
# precision_train1 = 0.734883721 recall_train1 = 0.730804810 f1_score_train1 = 0.732838590
# precision_te1 = 0.740157480 recall_te1 = 0.758064516 f1_score_te1 = 0.749003984
# precision_train2 = 0.704861111 recall_train2 = 0.638364780 f1_score_train2 = 0.669966997
# precision_te2 = 0.704545455 recall_te2 = 0.632653061 f1_score_te2 = 0.666666667
# ---------------Printing the Topics------------------
# sausag great scallop eel either itali tender pineappl hearti style rich trulli peke egg chines nut worth sometim around hour abl soundtrack boyfriend filet greasi care ultim taco beauti villag loaf becom broadway roll ice forev chair lettuc share stand root sear banana drop free interior aioli kobe settl radish
# java n smooth e mediocr away terribl either even charg age inspir waitress cater hip effici sichuan kobe stain spread sincer patient sliver date tier spill soundtrack respons citru feel move district trulli order without band attent magnifico dark paella soar ruin mismatch chopstick mod pollo bill machin loaf min
# children chines lit feel dark someth bakeri serv gossip filet midtown exist atmospher butter host might stylish citru silver stuck sliver intend fix mismatch spread limit fold red machin tang kept inch ultim shini patron gra mint great hearti sometim hard list weather environ roe kielbasa crispi make embarrass roast
# ---------------End of Topics------------------
# The approximated perplexity is:  2.1889289807180884e+25
# ##################################################
# ##################################################
# Epoch 40, loss=196.07315224095396, accuracy_train=0.7421647819063005, accuracy_test=0.752906976744186
# precision_train0 = 0.770330652 recall_train0 = 0.813207547 f1_score_train0 = 0.791188619
# precision_te0 = 0.779527559 recall_te0 = 0.811475410 f1_score_te0 = 0.795180723
# precision_train1 = 0.734177215 recall_train1 = 0.751156337 f1_score_train1 = 0.742569730
# precision_te1 = 0.753968254 recall_te1 = 0.766129032 f1_score_te1 = 0.760000000
# precision_train2 = 0.716091954 recall_train2 = 0.653039832 f1_score_train2 = 0.683114035
# precision_te2 = 0.714285714 recall_te2 = 0.663265306 f1_score_te2 = 0.687830688
# ---------------Printing the Topics------------------
# sausag great scallop eel either tender pineappl itali style egg hearti rich peke chicken trulli nut roll chines worth sometim loaf filet boyfriend greasi taco around sear soundtrack lettuc ice ultim beauti abl hour broadway care root share forev villag kobe known salt banana free famou becom die giovanni stand
# java n smooth e away waitress mediocr terribl even charg age either effici cater inspir order hip sincer kobe patient spread sichuan without attent stain date spill respons move sliver tier soundtrack take ruin band district min citru trulli feel paella chair mismatch magnifico rear bill mod money dark poor
# children lit feel chines dark bakeri atmospher someth filet serv gossip exist midtown might stylish butter silver host citru stuck sliver intend mismatch spread machin fix fold shini limit sometim inch kept red weather gra patron ultim tang hearti environ hard mint look make paint chair kielbasa great overhead crispi
# ---------------End of Topics------------------
# The approximated perplexity is:  1.8559371043589846e+25
# ##################################################
# ##################################################
# Epoch 45, loss=195.82083418996712, accuracy_train=0.7479806138933764, accuracy_test=0.7558139534883721
# precision_train0 = 0.787658802 recall_train0 = 0.818867925 f1_score_train0 = 0.802960222
# precision_te0 = 0.792000000 recall_te0 = 0.811475410 f1_score_te0 = 0.801619433
# precision_train1 = 0.735507246 recall_train1 = 0.751156337 f1_score_train1 = 0.743249428
# precision_te1 = 0.764227642 recall_te1 = 0.758064516 f1_score_te1 = 0.761133603
# precision_train2 = 0.714285714 recall_train2 = 0.665618449 f1_score_train2 = 0.689093869
# precision_te2 = 0.697916667 recall_te2 = 0.683673469 f1_score_te2 = 0.690721649
# ---------------Printing the Topics------------------
# sausag great scallop eel tender chicken either pineappl style egg roll itali hearti peke rich nut chines trulli worth sear loaf lettuc filet boyfriend taco greasi ice sometim ultim salt known soundtrack die beauti root kobe around giovanni share free bell top famou averag broadway banana octopu list aioli abl
# java n smooth waitress away e mediocr even terribl charg age order effici either cater sincer attent without take patient inspir hip kobe move date spill min respons spread ruin tier sichuan band soundtrack stain sliver chair district rear drink money poor trulli paella mod citru mismatch park bill owner
# feel lit dark children chines atmospher bakeri filet gossip serv exist midtown someth might butter stylish silver intend citru paint mismatch machin shini sometim host stuck weather fold chair sliver spread fix inch wooden look environ gra patron make limit hard overhead hearti kept ultim red soar strike tang mint
# ---------------End of Topics------------------
# The approximated perplexity is:  1.9576643174566857e+25
# ##################################################
# ##################################################
# Epoch 50, loss=195.81094520970396, accuracy_train=0.7508885298869143, accuracy_test=0.7645348837209303
# precision_train0 = 0.812680115 recall_train0 = 0.798113208 f1_score_train0 = 0.805330795
# precision_te0 = 0.833333333 recall_te0 = 0.778688525 f1_score_te0 = 0.805084746
# precision_train1 = 0.732283465 recall_train1 = 0.774283071 f1_score_train1 = 0.752697842
# precision_te1 = 0.746268657 recall_te1 = 0.806451613 f1_score_te1 = 0.775193798
# precision_train2 = 0.703622393 recall_train2 = 0.671907757 f1_score_train2 = 0.687399464
# precision_te2 = 0.708333333 recall_te2 = 0.693877551 f1_score_te2 = 0.701030928
# ---------------Printing the Topics------------------
# great sausag chicken scallop tender eel either roll pineappl style egg hearti itali peke sear nut rich chines loaf worth trulli lettuc filet grill taco salt known greasi boyfriend ice die menu top ultim sometim kobe root bell list giovanni free famou citru brais beauti octopu averag share banana soundtrack
# java n waitress smooth away even e terribl order mediocr charg age effici take either attent sincer without cater patient hip min ruin move spill inspir date drink kobe respons tier band spread money chair soundtrack rear poor sichuan owner stain mod abl need trulli park paella mismatch sliver district
# feel lit dark atmospher children chines bakeri gossip exist midtown might filet paint serv butter chair someth stylish wooden silver shini citru intend mismatch weather machin fold sometim look environ stuck soar host inch patron sliver fix spread strike make overhead weekday light embarrass gra inspir hard drape hearti limit
# ---------------End of Topics------------------
# The approximated perplexity is:  1.8168619611640215e+25
# ##################################################
# ##################################################
# Epoch 55, loss=195.7075221011513, accuracy_train=0.7625201938610663, accuracy_test=0.7674418604651163
# precision_train0 = 0.840521565 recall_train0 = 0.790566038 f1_score_train0 = 0.814778804
# precision_te0 = 0.862385321 recall_te0 = 0.770491803 f1_score_te0 = 0.813852814
# precision_train1 = 0.731442869 recall_train1 = 0.811285846 f1_score_train1 = 0.769298246
# precision_te1 = 0.728571429 recall_te1 = 0.822580645 f1_score_te1 = 0.772727273
# precision_train2 = 0.717463849 recall_train2 = 0.676100629 f1_score_train2 = 0.696168376
# precision_te2 = 0.715789474 recall_te2 = 0.693877551 f1_score_te2 = 0.704663212
# ---------------Printing the Topics------------------
# chicken great sausag scallop tender eel roll pineappl either style egg hearti sear grill peke itali loaf nut lettuc chines menu filet rich salt known greasi worth taco top trulli boyfriend die kobe ice citru root ultim list brais sometim bell octopu free giovanni famou averag dumpl banana sichuan share
# java n waitress smooth away even order e terribl take charg mediocr age effici attent without either sincer cater min patient ruin drink hip spill date move inspir money band need rear chair respons poor abl owner tier staff kobe soundtrack spread mod park bother trulli stain paella sichuan constantli
# feel lit dark atmospher chines children bakeri paint chair midtown might exist wooden gossip filet serv stylish shini butter silver weather mismatch intend look fold machin citru soar sometim someth light strike environ make inch weekday patron overhead stuck fix inspir host drape embarrass color deco spread sliver gone hard
# ---------------End of Topics------------------
# The approximated perplexity is:  1.6624659608486388e+25
# ##################################################
# ##################################################
# Epoch 60, loss=195.49378212376644, accuracy_train=0.769951534733441, accuracy_test=0.7790697674418605
# precision_train0 = 0.868835257 recall_train0 = 0.781132075 f1_score_train0 = 0.822652757
# precision_te0 = 0.910891089 recall_te0 = 0.754098361 f1_score_te0 = 0.825112108
# precision_train1 = 0.731234867 recall_train1 = 0.838112858 f1_score_train1 = 0.781034483
# precision_te1 = 0.726027397 recall_te1 = 0.854838710 f1_score_te1 = 0.785185185
# precision_train2 = 0.718715393 recall_train2 = 0.680293501 f1_score_train2 = 0.698976844
# precision_te2 = 0.721649485 recall_te2 = 0.714285714 f1_score_te2 = 0.717948718
# ---------------Printing the Topics------------------
# chicken great sausag tender scallop roll eel pineappl style egg either grill sear hearti menu loaf lettuc salt nut filet peke itali chines known top greasi rich kobe taco worth die ice boyfriend citru trulli brais octopu list root dumpl free averag ultim bell sichuan giovanni famou sometim share perfectli
# java n waitress smooth away order even take terribl e charg age effici attent mediocr without min either drink cater sincer patient ruin staff spill hip need date move money abl band poor inspir owner rear chair respons constantli soundtrack host tier mod kobe spread bother diet trulli came park
# feel lit dark atmospher chines paint bakeri chair children wooden midtown might exist shini gossip stylish look mismatch serv filet weather soar butter intend silver light fold strike machin color make citru sometim environ drape deco inspir inch weekday patron overhead someth area stuck fix embarrass host accent gone spread
# ---------------End of Topics------------------
# The approximated perplexity is:  1.7093302842481142e+25
# ##################################################
# ##################################################
# Epoch 65, loss=195.41914833470395, accuracy_train=0.7738287560581584, accuracy_test=0.7877906976744186
# precision_train0 = 0.881410256 recall_train0 = 0.778301887 f1_score_train0 = 0.826653307
# precision_te0 = 0.938144330 recall_te0 = 0.745901639 f1_score_te0 = 0.831050228
# precision_train1 = 0.722656250 recall_train1 = 0.855689177 f1_score_train1 = 0.783566285
# precision_te1 = 0.720779221 recall_te1 = 0.895161290 f1_score_te1 = 0.798561151
# precision_train2 = 0.733788396 recall_train2 = 0.676100629 f1_score_train2 = 0.703764321
# precision_te2 = 0.741935484 recall_te2 = 0.704081633 f1_score_te2 = 0.722513089
# ---------------Printing the Topics------------------
# chicken great sausag tender scallop roll eel grill pineappl egg style either menu sear hearti lettuc salt loaf filet top known nut peke kobe itali chines greasi rich taco die citru ice worth dumpl octopu boyfriend brais trulli root sichuan list free averag famou giovanni bell sometim ultim perfectli red
# java n waitress smooth away order even take terribl e attent charg age without effici min drink mediocr staff sincer either cater patient need ruin date spill move hip abl money owner host constantli poor band rear chair friendli respons inspir diet came soundtrack weekday mod tell bother tier welcom
# feel lit atmospher dark paint chair chines wooden bakeri midtown children might exist shini look soar mismatch stylish light color gossip strike weather intend area fold serv filet butter silver make deco machin drape environ inspir citru patron weekday inch overhead sometim stuck accent embarrass someth fix lie gone mod
# ---------------End of Topics------------------
# The approximated perplexity is:  1.6869703112901254e+25
# ##################################################
# ##################################################
# Epoch 70, loss=195.30626798930922, accuracy_train=0.7777059773828756, accuracy_test=0.7994186046511628
# precision_train0 = 0.898360656 recall_train0 = 0.775471698 f1_score_train0 = 0.832405063
# precision_te0 = 0.958333333 recall_te0 = 0.754098361 f1_score_te0 = 0.844036697
# precision_train1 = 0.711927982 recall_train1 = 0.877890842 f1_score_train1 = 0.786246893
# precision_te1 = 0.716981132 recall_te1 = 0.919354839 f1_score_te1 = 0.805653710
# precision_train2 = 0.750885478 recall_train2 = 0.666666667 f1_score_train2 = 0.706274292
# precision_te2 = 0.775280899 recall_te2 = 0.704081633 f1_score_te2 = 0.737967914
# ---------------Printing the Topics------------------
# chicken great sausag roll tender scallop grill eel pineappl egg style menu sear either salt lettuc hearti filet loaf top kobe known nut peke citru die chines greasi rich taco dumpl octopu itali brais ice boyfriend worth sichuan trulli list free root famou duck oil beef perfectli averag red giovanni
# java waitress n smooth order away take even terribl e attent without charg drink age min staff effici mediocr sincer need either cater patient ruin date host move constantli abl owner poor hip money friendli spill rear tell band reserv diet chair came respons weekday inspir bother forgotten bad problem
# feel dark atmospher lit paint chair wooden chines bakeri midtown look might shini exist color soar area children light mismatch stylish strike weather gossip fold intend deco make inspir drape serv environ machin silver butter filet patron weekday overhead sometim inch citru accent mod enclos stuck outdoor cater embarrass home
# ---------------End of Topics------------------
# The approximated perplexity is:  1.6162146279168732e+25
# ##################################################
# ##################################################
# Epoch 75, loss=195.2543521278783, accuracy_train=0.7809369951534734, accuracy_test=0.7965116279069767
# precision_train0 = 0.908888889 recall_train0 = 0.771698113 f1_score_train0 = 0.834693878
# precision_te0 = 0.957894737 recall_te0 = 0.745901639 f1_score_te0 = 0.838709677
# precision_train1 = 0.706140351 recall_train1 = 0.893617021 f1_score_train1 = 0.788893426
# precision_te1 = 0.712500000 recall_te1 = 0.919354839 f1_score_te1 = 0.802816901
# precision_train2 = 0.765417170 recall_train2 = 0.663522013 f1_score_train2 = 0.710836609
# precision_te2 = 0.775280899 recall_te2 = 0.704081633 f1_score_te2 = 0.737967914
# ---------------Printing the Topics------------------
# chicken great sausag roll tender scallop grill eel menu pineappl egg style sear either salt lettuc hearti filet kobe loaf top known citru nut dumpl rich peke octopu die chines taco brais greasi beef itali ice roast duck oil sichuan famou red list love root perfectli free trulli boyfriend dessert
# waitress n java smooth order away take even terribl attent without e drink staff charg min age effici sincer need mediocr either cater host patient ruin constantli friendli move date reserv owner abl poor hip money tell came spill rear diet chair band respons weekday forgotten bad around problem inspir
# feel dark atmospher lit chair paint wooden chines bakeri midtown look color area shini soar light might exist mismatch stylish fold strike weather deco intend make children gossip inspir drape machin environ silver serv weekday butter patron accent enclos overhead wood cozi mod franchis inch sometim filet citru outdoor home
# ---------------End of Topics------------------
# The approximated perplexity is:  1.5391028630384085e+25
# ##################################################
# ##################################################
# Epoch 80, loss=195.112451171875, accuracy_train=0.7851373182552503, accuracy_test=0.8023255813953488
# precision_train0 = 0.916013438 recall_train0 = 0.771698113 f1_score_train0 = 0.837685612
# precision_te0 = 0.948453608 recall_te0 = 0.754098361 f1_score_te0 = 0.840182648
# precision_train1 = 0.704103672 recall_train1 = 0.904717854 f1_score_train1 = 0.791902834
# precision_te1 = 0.718750000 recall_te1 = 0.927419355 f1_score_te1 = 0.809859155
# precision_train2 = 0.779827798 recall_train2 = 0.664570231 f1_score_train2 = 0.717600453
# precision_te2 = 0.793103448 recall_te2 = 0.704081633 f1_score_te2 = 0.745945946
# ---------------Printing the Topics------------------
# chicken great sausag roll tender scallop grill eel menu pineappl egg sear style salt either lettuc hearti kobe filet loaf known citru top beef dumpl roast octopu rich nut die brais taco greasi chines peke duck oil itali ice sichuan love red famou dessert homemad root free perfectli pollo list
# waitress n java smooth order take away even terribl without staff drink attent e min charg age effici need sincer host mediocr reserv friendli cater constantli either patient owner move ruin abl date poor tell hip money came spill rear forgotten diet around bad respons band weekday chair problem intend
# feel dark atmospher lit chair paint wooden chines look color area bakeri midtown shini soar light mismatch might fold stylish strike exist deco weather make intend inspir drape wood gossip cozi machin enclos silver franchis accent environ overhead mod weekday tone butter patron children inch cater sometim serv outdoor embarrass
# ---------------End of Topics------------------
# The approximated perplexity is:  1.4465727882616329e+25
# ##################################################
# ##################################################
# Epoch 85, loss=195.07544459292762, accuracy_train=0.787075928917609, accuracy_test=0.8052325581395349
# precision_train0 = 0.924122310 recall_train0 = 0.769811321 f1_score_train0 = 0.839938240
# precision_te0 = 0.968085106 recall_te0 = 0.745901639 f1_score_te0 = 0.842592593
# precision_train1 = 0.700848656 recall_train1 = 0.916743756 f1_score_train1 = 0.794388778
# precision_te1 = 0.715151515 recall_te1 = 0.951612903 f1_score_te1 = 0.816608997
# precision_train2 = 0.788220551 recall_train2 = 0.659329140 f1_score_train2 = 0.718036530
# precision_te2 = 0.800000000 recall_te2 = 0.693877551 f1_score_te2 = 0.743169399
# ---------------Printing the Topics------------------
# chicken sausag great roll grill scallop tender menu eel pineappl sear egg style salt lettuc either kobe hearti filet roast beef loaf citru dumpl known octopu rich top brais nut taco die greasi chines duck peke oil love sichuan dessert famou homemad itali ice red root free perfectli pollo sweet
# waitress n java smooth take order away even terribl without staff drink attent min e charg effici age need reserv host sincer mediocr friendli constantli owner either patient cater abl tell move ruin came poor date hip money around bad forgotten spill diet respons problem rear intend inattent band model
# feel dark atmospher lit chair paint wooden look color chines area bakeri midtown shini soar light strike mismatch fold stylish might wood deco cozi weather exist inspir intend franchis enclos make silver drape machin accent tone mod gossip overhead environ weekday cater patron outdoor inch confin mirror embarrass butter lie
# ---------------End of Topics------------------
# The approximated perplexity is:  1.4352096362997125e+25
# ##################################################
# ##################################################
# Epoch 90, loss=194.85964869449012, accuracy_train=0.7922455573505655, accuracy_test=0.7994186046511628
# precision_train0 = 0.934557979 recall_train0 = 0.767924528 f1_score_train0 = 0.843086484
# precision_te0 = 0.978021978 recall_te0 = 0.729508197 f1_score_te0 = 0.835680751
# precision_train1 = 0.701607268 recall_train1 = 0.928769658 f1_score_train1 = 0.799363057
# precision_te1 = 0.694117647 recall_te1 = 0.951612903 f1_score_te1 = 0.802721088
# precision_train2 = 0.799495586 recall_train2 = 0.664570231 f1_score_train2 = 0.725815684
# precision_te2 = 0.819277108 recall_te2 = 0.693877551 f1_score_te2 = 0.751381215
# ---------------Printing the Topics------------------
# chicken sausag great roll grill scallop tender menu eel pineappl sear style egg salt roast lettuc beef kobe either hearti filet citru loaf dumpl known rich octopu brais nut taco die top greasi duck oil chines peke love sichuan homemad dessert famou veget red ice sweet perfectli root itali free
# waitress n java take order smooth away even terribl staff without attent drink min charg reserv e effici need age host sincer friendli constantli mediocr owner tell patient either abl move cater came ruin bad around poor money date hip forgotten spill problem inattent respons diet though model intend bother
# feel dark atmospher lit chair paint wooden look color area chines bakeri shini midtown soar light strike wood cozi mismatch stylish fold deco might franchis inspir weather tone enclos exist silver intend accent machin mod overhead make drape environ cater gossip outdoor weekday tabl dim patron mirror inch confin embarrass
# ---------------End of Topics------------------
# The approximated perplexity is:  1.4976896039161218e+25
# ##################################################
# ##################################################
# Epoch 95, loss=194.79215152138158, accuracy_train=0.7967689822294023, accuracy_test=0.7965116279069767
# precision_train0 = 0.939289805 recall_train0 = 0.773584906 f1_score_train0 = 0.848422142
# precision_te0 = 0.978021978 recall_te0 = 0.729508197 f1_score_te0 = 0.835680751
# precision_train1 = 0.701596114 recall_train1 = 0.935245143 f1_score_train1 = 0.801744647
# precision_te1 = 0.682080925 recall_te1 = 0.951612903 f1_score_te1 = 0.794612795
# precision_train2 = 0.813060179 recall_train2 = 0.665618449 f1_score_train2 = 0.731988473
# precision_te2 = 0.837500000 recall_te2 = 0.683673469 f1_score_te2 = 0.752808989
# ---------------Printing the Topics------------------
# chicken sausag great roll grill scallop tender menu eel sear pineappl roast style egg beef salt lettuc kobe either filet hearti citru loaf dumpl rich known octopu brais die nut taco greasi top duck oil homemad love chines dessert peke sichuan creami famou veget sweet red root gener perfectli ice
# waitress n java take order smooth away even terribl staff without attent drink min reserv charg need effici e host age sincer friendli constantli tell mediocr owner abl patient came bad either move cater ruin around problem poor money inattent forgotten hip spill date though bold diet model respons bother
# feel dark atmospher lit chair paint wooden look color area bakeri chines midtown shini soar wood light strike cozi mismatch stylish franchis deco tone fold inspir might weather silver enclos intend accent mod machin exist environ overhead outdoor tabl dim mirror make place cater drape weekday gossip inch patron ceil
# ---------------End of Topics------------------
# The approximated perplexity is:  1.5858560914649715e+25
# ##################################################
# ##################################################
# Epoch 100, loss=194.62125436883224, accuracy_train=0.8048465266558966, accuracy_test=0.8052325581395349
# precision_train0 = 0.941043084 recall_train0 = 0.783018868 f1_score_train0 = 0.854788877
# precision_te0 = 0.978494624 recall_te0 = 0.745901639 f1_score_te0 = 0.846511628
# precision_train1 = 0.708798883 recall_train1 = 0.938945421 f1_score_train1 = 0.807799443
# precision_te1 = 0.698224852 recall_te1 = 0.951612903 f1_score_te1 = 0.805460751
# precision_train2 = 0.827144686 recall_train2 = 0.677148847 f1_score_train2 = 0.744668588
# precision_te2 = 0.829268293 recall_te2 = 0.693877551 f1_score_te2 = 0.755555556
# ---------------Printing the Topics------------------
# chicken sausag roll great scallop grill tender menu eel sear roast pineappl beef style egg salt lettuc kobe either filet citru hearti dumpl loaf rich known brais octopu die nut greasi taco duck oil creami top homemad sichuan dessert shrimp love famou peke veget chines red gener sweet perfectli spici
# waitress n java take order away smooth even terribl staff without drink attent reserv min charg need host effici e age friendli sincer tell constantli mediocr bad came owner patient abl move either cater around ruin problem inattent poor forgotten money bold though bother hip spill diet date model intend
# feel dark atmospher chair lit paint wooden look color area bakeri midtown chines shini wood soar cozi strike light mismatch franchis tone stylish deco inspir weather fold silver place might enclos accent mod mirror tabl dim intend outdoor environ machin overhead cater drape inch tier exist ceil weekday make gossip
# ---------------End of Topics------------------
# The approximated perplexity is:  1.4027553145816709e+25
# ##################################################
# ##################################################
# Epoch 105, loss=194.7167878803454, accuracy_train=0.8096930533117932, accuracy_test=0.811046511627907
# precision_train0 = 0.944695260 recall_train0 = 0.789622642 f1_score_train0 = 0.860226105
# precision_te0 = 0.978494624 recall_te0 = 0.745901639 f1_score_te0 = 0.846511628
# precision_train1 = 0.709318498 recall_train1 = 0.943570768 f1_score_train1 = 0.809845177
# precision_te1 = 0.693641618 recall_te1 = 0.967741935 f1_score_te1 = 0.808080808
# precision_train2 = 0.841763943 recall_train2 = 0.680293501 f1_score_train2 = 0.752463768
# precision_te2 = 0.871794872 recall_te2 = 0.693877551 f1_score_te2 = 0.772727273
# ---------------Printing the Topics------------------
# chicken sausag roll scallop grill great tender menu eel roast sear beef pineappl salt lettuc kobe style egg citru filet either hearti loaf dumpl rich brais known die octopu nut greasi duck shrimp creami taco homemad oil sichuan dessert top famou veget gener peke green love spici red sweet chipotl
# waitress n java take order away smooth even terribl staff without reserv drink attent min charg need host effici e tell friendli constantli age sincer bad mediocr came patient owner abl move around problem ruin inattent either cater poor forgotten bold money though bother model diet spill respons hip waiter
# feel dark chair lit atmospher wooden paint look color area bakeri wood chines midtown shini cozi soar strike light mismatch franchis tone stylish place inspir deco weather accent silver fold tabl dim mirror enclos mod might outdoor environ cater overhead drape tier intend ceil machin band inch ba weekday patron
# ---------------End of Topics------------------
# The approximated perplexity is:  1.4190171378004082e+25
# ##################################################
# ##################################################
# Epoch 110, loss=194.5977937397204, accuracy_train=0.812924071082391, accuracy_test=0.811046511627907
# precision_train0 = 0.950056754 recall_train0 = 0.789622642 f1_score_train0 = 0.862442040
# precision_te0 = 0.978494624 recall_te0 = 0.745901639 f1_score_te0 = 0.846511628
# precision_train1 = 0.710325710 recall_train1 = 0.948196115 f1_score_train1 = 0.812202853
# precision_te1 = 0.693641618 recall_te1 = 0.967741935 f1_score_te1 = 0.808080808
# precision_train2 = 0.848249027 recall_train2 = 0.685534591 f1_score_train2 = 0.758260870
# precision_te2 = 0.871794872 recall_te2 = 0.693877551 f1_score_te2 = 0.772727273
# ---------------Printing the Topics------------------
# chicken sausag roll grill scallop great tender menu eel roast sear beef pineappl salt lettuc kobe filet egg citru style either hearti dumpl loaf brais rich known shrimp die octopu nut creami homemad greasi duck oil taco sichuan green dessert veget gener famou spici peke sweet love kielbasa red chipotl
# waitress n java take order away even smooth terribl staff without reserv drink attent min charg need host effici tell constantli friendli e sincer age came bad mediocr abl patient owner problem move around inattent ruin poor bold cater though forgotten either bother money waiter model bill intend diet welcom
# feel dark chair lit atmospher wooden paint look color area wood cozi bakeri midtown shini chines soar strike tone franchis light mismatch place stylish inspir deco weather accent silver tabl dim mirror enclos mod fold outdoor might cater overhead environ tier ceil drape band inch ba intend machin patron carpet
# ---------------End of Topics------------------
# The approximated perplexity is:  1.2544143748648194e+25
# ##################################################
# ##################################################
# Epoch 115, loss=194.46833753083882, accuracy_train=0.8122778675282714, accuracy_test=0.8197674418604651
# precision_train0 = 0.954285714 recall_train0 = 0.787735849 f1_score_train0 = 0.863049096
# precision_te0 = 0.989247312 recall_te0 = 0.754098361 f1_score_te0 = 0.855813953
# precision_train1 = 0.705841924 recall_train1 = 0.950046253 f1_score_train1 = 0.809936909
# precision_te1 = 0.699421965 recall_te1 = 0.975806452 f1_score_te1 = 0.814814815
# precision_train2 = 0.852287582 recall_train2 = 0.683438155 f1_score_train2 = 0.758580570
# precision_te2 = 0.884615385 recall_te2 = 0.704081633 f1_score_te2 = 0.784090909
# ---------------Printing the Topics------------------
# chicken sausag roll grill scallop tender great menu roast eel sear beef pineappl lettuc salt kobe filet citru egg style either hearti dumpl loaf brais shrimp rich known die creami nut octopu homemad duck greasi oil green sichuan dessert taco gener veget famou spici peke sweet root kielbasa chipotl red
# waitress n java take order away even smooth terribl reserv staff without drink attent min need charg host effici tell constantli friendli e came bad sincer mediocr age owner problem around patient move abl inattent poor bold though ruin bother cater waiter forgotten money either model bill intend spill welcom
# feel dark chair lit atmospher wooden paint look color area cozi wood shini bakeri midtown tone strike soar chines franchis place light mismatch stylish inspir tabl deco dim silver weather accent mirror outdoor mod enclos fold tier overhead cater ceil ba might environ drape band carpet inch patron sincer machin
# ---------------End of Topics------------------
# The approximated perplexity is:  1.3095345565854617e+25
# ##################################################
# ##################################################
# Epoch 120, loss=194.4062191611842, accuracy_train=0.8161550888529887, accuracy_test=0.8284883720930233
# precision_train0 = 0.956719818 recall_train0 = 0.792452830 f1_score_train0 = 0.866873065
# precision_te0 = 0.989473684 recall_te0 = 0.770491803 f1_score_te0 = 0.866359447
# precision_train1 = 0.708965517 recall_train1 = 0.950971323 f1_score_train1 = 0.812327143
# precision_te1 = 0.703488372 recall_te1 = 0.975806452 f1_score_te1 = 0.817567568
# precision_train2 = 0.857887875 recall_train2 = 0.689727463 f1_score_train2 = 0.764671702
# precision_te2 = 0.909090909 recall_te2 = 0.714285714 f1_score_te2 = 0.800000000
# ---------------Printing the Topics------------------
# chicken sausag roll grill scallop tender menu great roast eel sear beef pineappl lettuc kobe salt filet citru egg either dumpl hearti style loaf shrimp brais creami rich die known homemad octopu nut duck oil green greasi gener dessert sichuan veget taco famou spici peke chipotl root kielbasa sweet perfectli
# waitress n java take away even order smooth terribl reserv staff without drink attent min need charg host tell effici constantli came bad friendli e sincer mediocr age problem inattent around owner patient move though bold abl poor bother ruin waiter cater forgotten bill money model spill intend new either
# feel dark chair lit wooden atmospher paint look color cozi wood area shini tone bakeri franchis midtown place strike soar chines mismatch light inspir stylish dim tabl deco accent silver weather mirror outdoor mod ba enclos tier overhead ceil carpet fold cater band environ drape might inch patron neon laden
# ---------------End of Topics------------------
# The approximated perplexity is:  1.2731230651105529e+25
# ##################################################
# ##################################################
# Epoch 125, loss=194.31519968133225, accuracy_train=0.8177705977382875, accuracy_test=0.8313953488372093
# precision_train0 = 0.956621005 recall_train0 = 0.790566038 f1_score_train0 = 0.865702479
# precision_te0 = 0.989583333 recall_te0 = 0.778688525 f1_score_te0 = 0.871559633
# precision_train1 = 0.709744299 recall_train1 = 0.950046253 f1_score_train1 = 0.812500000
# precision_te1 = 0.703488372 recall_te1 = 0.975806452 f1_score_te1 = 0.817567568
# precision_train2 = 0.862694301 recall_train2 = 0.698113208 f1_score_train2 = 0.771726535
# precision_te2 = 0.921052632 recall_te2 = 0.714285714 f1_score_te2 = 0.804597701
# ---------------Printing the Topics------------------
# chicken sausag roll scallop grill tender menu great roast eel sear beef pineappl kobe lettuc filet salt citru either hearti dumpl egg shrimp loaf style brais creami die rich homemad known octopu nut green greasi dessert oil duck gener sichuan veget taco famou spici root peke tofu perfectli kielbasa chipotl
# waitress n java take even away order reserv terribl smooth staff without drink min attent need charg host tell constantli effici bad came friendli sincer e mediocr inattent problem owner around though age patient move bold waiter bother ruin abl poor cater forgotten bill spill new model money confirm diet
# feel dark chair lit wooden paint atmospher look color cozi wood area tone shini place franchis bakeri soar midtown strike chines mismatch light inspir stylish dim tabl accent deco mirror silver outdoor weather ba mod tier ceil enclos overhead carpet cater fold band environ drape patron inch might neon subway
# ---------------End of Topics------------------
# The approximated perplexity is:  1.2686557178846798e+25
# ##################################################
# ##################################################
# Epoch 130, loss=194.2785952919408, accuracy_train=0.8184168012924071, accuracy_test=0.8343023255813954
# precision_train0 = 0.957714286 recall_train0 = 0.790566038 f1_score_train0 = 0.866149871
# precision_te0 = 0.989583333 recall_te0 = 0.778688525 f1_score_te0 = 0.871559633
# precision_train1 = 0.706932052 recall_train1 = 0.952821462 f1_score_train1 = 0.811662727
# precision_te1 = 0.705202312 recall_te1 = 0.983870968 f1_score_te1 = 0.821548822
# precision_train2 = 0.871559633 recall_train2 = 0.697064990 f1_score_train2 = 0.774606872
# precision_te2 = 0.933333333 recall_te2 = 0.714285714 f1_score_te2 = 0.809248555
# ---------------Printing the Topics------------------
# ...
# precision_train0 = 0.963302752 recall_train0 = 0.792452830 f1_score_train0 = 0.869565217
# precision_te0 = 0.989583333 recall_te0 = 0.778688525 f1_score_te0 = 0.871559633
# precision_train1 = 0.712413793 recall_train1 = 0.955596670 f1_score_train1 = 0.816278151
# precision_te1 = 0.705202312 recall_te1 = 0.983870968 f1_score_te1 = 0.821548822
# precision_train2 = 0.884864166 recall_train2 = 0.716981132 f1_score_train2 = 0.792125072
# precision_te2 = 0.933333333 recall_te2 = 0.714285714 f1_score_te2 = 0.809248555
# ---------------Printing the Topics------------------
# chicken sausag roll scallop grill tender menu roast eel sear beef pineappl kobe great filet lettuc citru hearti salt shrimp dumpl creami brais loaf either homemad duck egg nut dessert die greasi octopu root gener oil tofu green sichuan rich veget perfectli kielbasa miso style peke foie salmon famou chipotl
# waitress n java take even reserv away terribl order without staff min smooth drink need attent charg tell host bad constantli came effici sincer us inattent mediocr problem friendli bold waiter though bother new e owner patient forgotten move go hour spill around ruin wrong poor anoth bill diet confirm
# feel dark chair lit wooden paint color atmospher cozi look wood tone place franchis soar area shini deco mirror midtown mismatch dim bakeri strike stylish accent outdoor tier mod ba silver inspir ceil weather chines tabl lamp enclos overhead carpet band cater fold light neon inch spaciou environ villag rear
# ---------------End of Topics------------------
# The approximated perplexity is:  1.1350913756673473e+25
# ##################################################
# ##################################################
# Epoch 160, loss=194.02911441200658, accuracy_train=0.8248788368336026, accuracy_test=0.8343023255813954
# precision_train0 = 0.963302752 recall_train0 = 0.792452830 f1_score_train0 = 0.869565217
# precision_te0 = 0.989583333 recall_te0 = 0.778688525 f1_score_te0 = 0.871559633
# precision_train1 = 0.709190672 recall_train1 = 0.956521739 f1_score_train1 = 0.814493895
# precision_te1 = 0.705202312 recall_te1 = 0.983870968 f1_score_te1 = 0.821548822
# precision_train2 = 0.887581699 recall_train2 = 0.711740042 f1_score_train2 = 0.789994183
# precision_te2 = 0.933333333 recall_te2 = 0.714285714 f1_score_te2 = 0.809248555
# ---------------Printing the Topics------------------
# chicken sausag roll scallop grill tender menu roast sear eel kobe pineappl beef lettuc filet great hearti citru salt shrimp brais dumpl creami loaf either duck homemad root nut dessert octopu egg die greasi tofu oil gener sichuan green rich veget perfectli miso kielbasa foie salmon peke famou chipotl pepper
# waitress n java take even reserv away terribl without order min staff smooth drink attent need charg tell bad host constantli came effici us sincer inattent problem mediocr bold friendli waiter though bother new e hour forgotten patient go owner move spill ruin diet anoth poor around got wrong bill
# feel dark chair wooden lit paint color atmospher cozi tone wood look place franchis soar area shini deco mirror midtown mismatch dim accent strike bakeri stylish tier outdoor ba mod silver inspir weather ceil chines lamp tabl carpet overhead enclos band cater neon fold spaciou light inch villag drape rear
# ---------------End of Topics------------------
# The approximated perplexity is:  1.1426113129626993e+25
# ##################################################
# ##################################################
# Epoch 165, loss=193.951806640625, accuracy_train=0.8261712439418417, accuracy_test=0.8313953488372093
# precision_train0 = 0.965556831 recall_train0 = 0.793396226 f1_score_train0 = 0.871051269
# precision_te0 = 0.989473684 recall_te0 = 0.770491803 f1_score_te0 = 0.866359447
# precision_train1 = 0.709103354 recall_train1 = 0.958371878 f1_score_train1 = 0.815106216
# precision_te1 = 0.701149425 recall_te1 = 0.983870968 f1_score_te1 = 0.818791946
# precision_train2 = 0.891218873 recall_train2 = 0.712788260 f1_score_train2 = 0.792079208
# precision_te2 = 0.933333333 recall_te2 = 0.714285714 f1_score_te2 = 0.809248555
# ---------------Printing the Topics------------------
# chicken sausag scallop roll tender grill menu roast sear eel kobe pineappl beef lettuc filet hearti citru great shrimp salt brais creami loaf dumpl either duck homemad root octopu nut dessert tofu egg die oil greasi gener rich sichuan green veget perfectli foie miso kielbasa salmon peke famou pepper piec
# n waitress java take even reserv away terribl without min staff order smooth attent need drink charg tell bad host constantli us effici came sincer problem inattent mediocr bold waiter friendli though hour bother e go new patient forgotten diet spill move owner got ruin anoth bill poor confirm around
# feel dark chair wooden lit paint color atmospher tone cozi wood franchis place look soar area shini deco mirror midtown accent dim mismatch strike tier outdoor ba mod stylish bakeri silver inspir ceil weather lamp chines tabl carpet overhead enclos band cater neon spaciou fold villag inch drape rear environ
# ---------------End of Topics------------------
# The approximated perplexity is:  1.0194480352873178e+25
# ##################################################
# ##################################################
# Epoch 170, loss=193.89554893092105, accuracy_train=0.8274636510500808, accuracy_test=0.8343023255813954
# precision_train0 = 0.966628308 recall_train0 = 0.792452830 f1_score_train0 = 0.870917574
# precision_te0 = 0.989583333 recall_te0 = 0.778688525 f1_score_te0 = 0.871559633
# precision_train1 = 0.711340206 recall_train1 = 0.957446809 f1_score_train1 = 0.816246057
# precision_te1 = 0.705202312 recall_te1 = 0.983870968 f1_score_te1 = 0.821548822
# precision_train2 = 0.889753567 recall_train2 = 0.719077568 f1_score_train2 = 0.795362319
# precision_te2 = 0.933333333 recall_te2 = 0.714285714 f1_score_te2 = 0.809248555
# ---------------Printing the Topics------------------
# chicken sausag scallop roll tender grill menu roast sear eel kobe pineappl beef lettuc filet hearti citru shrimp salt creami great brais loaf dumpl duck root octopu homemad either nut tofu dessert die egg greasi oil gener rich sichuan perfectli green foie veget miso kielbasa salmon piec pepper famou peke
# n waitress java take even reserv away terribl min without staff order smooth need attent charg drink tell bad host constantli us effici came sincer problem inattent mediocr bold hour waiter though bother friendli go patient e new diet forgotten spill got bill move anoth poor ruin owner confirm wrong
# feel dark chair wooden lit paint color atmospher tone cozi wood franchis place soar look shini deco mirror area midtown accent tier strike dim outdoor ba mod mismatch stylish silver bakeri lamp ceil weather inspir carpet overhead enclos band tabl chines cater spaciou neon villag inch drape fold rear environ
# ---------------End of Topics------------------
# The approximated perplexity is:  1.102905802999514e+25
# ##################################################
# ##################################################
# Epoch 175, loss=193.91462659333882, accuracy_train=0.827140549273021, accuracy_test=0.8343023255813954
# precision_train0 = 0.967853042 recall_train0 = 0.795283019 f1_score_train0 = 0.873122734
# precision_te0 = 0.989583333 recall_te0 = 0.778688525 f1_score_te0 = 0.871559633
# precision_train1 = 0.707934337 recall_train1 = 0.957446809 f1_score_train1 = 0.813999214
# precision_te1 = 0.705202312 recall_te1 = 0.983870968 f1_score_te1 = 0.821548822
# precision_train2 = 0.895013123 recall_train2 = 0.714884696 f1_score_train2 = 0.794871795
# precision_te2 = 0.933333333 recall_te2 = 0.714285714 f1_score_te2 = 0.809248555
# ---------------Printing the Topics------------------
# chicken sausag scallop tender roll grill menu roast sear eel kobe pineappl beef filet lettuc hearti citru creami shrimp salt brais loaf dumpl great duck root octopu homemad tofu either nut dessert greasi oil die egg gener foie sichuan rich miso green kielbasa perfectli veget salmon piec pepper famou peke
# n waitress java take even reserv away terribl min without staff need smooth order attent charg drink tell bad host us constantli effici came sincer problem inattent mediocr hour bold waiter though go bother patient friendli diet e spill new got forgotten bill anoth confirm move ruin poor wrong owner
# feel chair dark wooden lit paint color tone atmospher cozi wood franchis place soar look shini deco mirror midtown accent area strike tier outdoor ba dim mod stylish mismatch silver lamp weather ceil bakeri inspir overhead band carpet enclos chines tabl cater spaciou neon villag drape inch rear poster fold
# ---------------End of Topics------------------
# The approximated perplexity is:  1.060678904172117e+25
# ##################################################
# ##################################################
# Epoch 180, loss=193.8676513671875, accuracy_train=0.830048465266559, accuracy_test=0.8343023255813954
# precision_train0 = 0.968965517 recall_train0 = 0.795283019 f1_score_train0 = 0.873575130
# precision_te0 = 0.989583333 recall_te0 = 0.778688525 f1_score_te0 = 0.871559633
# precision_train1 = 0.711829436 recall_train1 = 0.957446809 f1_score_train1 = 0.816568047
# precision_te1 = 0.705202312 recall_te1 = 0.983870968 f1_score_te1 = 0.821548822
# precision_train2 = 0.896238651 recall_train2 = 0.724318658 f1_score_train2 = 0.801159420
# precision_te2 = 0.933333333 recall_te2 = 0.714285714 f1_score_te2 = 0.809248555
# ---------------Printing the Topics------------------
# chicken sausag scallop tender roll grill roast menu sear eel kobe pineappl beef filet hearti lettuc citru creami shrimp loaf brais salt dumpl great duck octopu root tofu homemad nut either dessert greasi oil gener die egg foie kielbasa miso sichuan veget green rich salmon perfectli famou pepper peke chipotl
# n waitress java take even reserv away terribl min without staff need smooth charg attent order tell drink bad us host constantli effici sincer came problem inattent mediocr hour bold waiter though go patient bother spill got diet forgotten bill new friendli e confirm ruin anoth poor move wrong embarrass
# feel chair dark wooden lit paint color tone franchis cozi atmospher wood soar place look shini deco midtown mirror accent strike outdoor area ba tier dim mod stylish lamp silver mismatch weather ceil bakeri overhead inspir band carpet enclos chines spaciou tabl cater neon villag drape rear poster rail environ
# ---------------End of Topics------------------
# The approximated perplexity is:  1.108524167109449e+25
# ##################################################
# ##################################################
# Epoch 185, loss=193.7811279296875, accuracy_train=0.8281098546042003, accuracy_test=0.8313953488372093
# precision_train0 = 0.971098266 recall_train0 = 0.792452830 f1_score_train0 = 0.872727273
# precision_te0 = 0.989473684 recall_te0 = 0.770491803 f1_score_te0 = 0.866359447
# precision_train1 = 0.707084469 recall_train1 = 0.960222017 f1_score_train1 = 0.814437034
# precision_te1 = 0.701149425 recall_te1 = 0.983870968 f1_score_te1 = 0.818791946
# precision_train2 = 0.898950131 recall_train2 = 0.718029350 f1_score_train2 = 0.798368298
# precision_te2 = 0.933333333 recall_te2 = 0.714285714 f1_score_te2 = 0.809248555
# ---------------Printing the Topics------------------
# chicken sausag scallop tender roll grill roast menu sear eel kobe pineappl beef hearti filet lettuc citru creami loaf shrimp brais salt dumpl duck octopu great tofu root homemad either nut greasi oil gener dessert die foie egg kielbasa miso veget sichuan salmon perfectli rich green famou chipotl pepper peke
# n waitress java take even reserv terribl away min without staff need charg attent smooth tell order drink us bad host constantli effici sincer inattent problem hour came mediocr bold waiter patient go spill though bother got diet bill confirm forgotten poor new e ruin anoth wrong embarrass move friendli
# feel chair dark wooden lit paint color tone franchis soar cozi wood atmospher place shini look deco midtown mirror accent outdoor ba strike tier dim mod lamp stylish area silver mismatch ceil weather overhead inspir band carpet bakeri spaciou enclos chines neon cater tabl villag drape rear rail environ poster
# ---------------End of Topics------------------
# The approximated perplexity is:  1.0354228398568014e+25
# ##################################################
# ##################################################
# Epoch 190, loss=193.85395250822367, accuracy_train=0.827140549273021, accuracy_test=0.8313953488372093
# precision_train0 = 0.970930233 recall_train0 = 0.787735849 f1_score_train0 = 0.869791667
# precision_te0 = 0.989473684 recall_te0 = 0.770491803 f1_score_te0 = 0.866359447
# precision_train1 = 0.705363204 recall_train1 = 0.961147086 f1_score_train1 = 0.813625685
# precision_te1 = 0.701149425 recall_te1 = 0.983870968 f1_score_te1 = 0.818791946
# precision_train2 = 0.900262467 recall_train2 = 0.719077568 f1_score_train2 = 0.799533800
# precision_te2 = 0.933333333 recall_te2 = 0.714285714 f1_score_te2 = 0.809248555
# ---------------Printing the Topics------------------
# chicken sausag scallop tender roll grill roast menu sear eel kobe pineappl beef hearti filet lettuc citru creami loaf brais shrimp dumpl salt duck octopu tofu nut either root great homemad greasi oil gener dessert die foie egg kielbasa miso veget salmon perfectli rich sichuan chipotl pepper green famou highlight
# n waitress java take even reserv terribl away min without staff need attent charg tell smooth order us drink host bad constantli effici sincer inattent hour problem came mediocr bold waiter patient spill go got bother though diet bill confirm embarrass forgotten poor ruin anoth e wrong wo new last
# feel chair dark wooden lit paint color tone franchis soar cozi wood place atmospher deco shini mirror midtown look accent tier ba outdoor dim strike lamp stylish mod area silver mismatch weather ceil overhead inspir carpet band spaciou enclos bakeri neon chines cater villag rear tabl rail drape poster environ
# ---------------End of Topics------------------
# The approximated perplexity is:  1.0359910413469554e+25
# ##################################################
# ##################################################
# Epoch 195, loss=193.80385228207237, accuracy_train=0.8297253634894992, accuracy_test=0.8372093023255814
# precision_train0 = 0.971031286 recall_train0 = 0.790566038 f1_score_train0 = 0.871554862
# precision_te0 = 0.989583333 recall_te0 = 0.778688525 f1_score_te0 = 0.871559633
# precision_train1 = 0.708731241 recall_train1 = 0.961147086 f1_score_train1 = 0.815861798
# precision_te1 = 0.709302326 recall_te1 = 0.983870968 f1_score_te1 = 0.824324324
# precision_train2 = 0.902088773 recall_train2 = 0.724318658 f1_score_train2 = 0.803488372
# precision_te2 = 0.934210526 recall_te2 = 0.724489796 f1_score_te2 = 0.816091954
# ---------------Printing the Topics------------------
# chicken sausag scallop tender roll grill roast menu eel sear kobe pineappl beef filet hearti lettuc citru creami loaf brais shrimp dumpl salt duck tofu octopu nut root either homemad greasi oil great gener die foie miso dessert kielbasa egg veget salmon perfectli chipotl rich sichuan pepper peke highlight famou
# n waitress java take even reserv terribl away min without staff need charg attent tell smooth us constantli host order drink bad effici inattent hour sincer problem mediocr came bold waiter patient got spill go bother though diet embarrass poor confirm ruin bill anoth wo e forgotten last wrong new
# feel chair dark wooden lit paint color tone franchis soar cozi wood place atmospher deco mirror shini midtown tier accent look ba mod dim outdoor strike lamp stylish area silver ceil weather mismatch overhead inspir carpet enclos band spaciou neon chines bakeri villag rear cater rail drape poster environ tabl
# ---------------End of Topics------------------
# The approximated perplexity is:  1.0164192917035787e+25
# ##################################################

# %% [markdown]
# ## Test

# %%
model.eval()
gamma_mean, gamma_logvar = model.gamma()
gm, gl = gamma_mean.data.cpu().numpy(), gamma_logvar.data.cpu().numpy()
print_gamma(gm, seed_words, vocab, vocab2id)
# Out:
# 935 food 0 1 [0.24964267 0.5249344  0.225423  ]
# 88 sauc 0 0 [0.48584357 0.2489847  0.26517174]
# 2681 chicken 0 0 [0.43324354 0.26412746 0.30262896]
# 2414 shrimp 0 1 [0.35139   0.4001237 0.2484864]
# 1381 chees 0 1 [0.31703988 0.37503672 0.30792344]
# 1496 potato 0 1 [0.30937544 0.46532995 0.22529462]
# 105 fri 0 2 [0.3354963  0.30596307 0.3585406 ]
# 546 tomato 0 2 [0.35161608 0.29045445 0.35792953]
# 1347 roast 0 0 [0.43419012 0.33292595 0.23288386]
# 642 onion 0 1 [0.33218953 0.43471566 0.23309481]
# 2272 pork 0 0 [0.35807046 0.35356387 0.2883656 ]
# 872 goat 0 1 [0.32960615 0.3879351  0.28245872]
# 1005 grill 0 1 [0.21808502 0.507333   0.27458197]
# 124 tuna 0 1 [0.35623774 0.42428207 0.21948016]
# 1159 salad 0 0 [0.4088579  0.31646934 0.27467275]
# 2188 beef 0 1 [0.34266505 0.4064603  0.2508747 ]
# 601 tapa 0 1 [0.29188886 0.39962614 0.30848497]
# 1991 staff 1 1 [0.20411542 0.6123133  0.18357132]
# 1425 servic 1 1 [0.16824763 0.595536   0.2362164 ]
# 1137 friendli 1 1 [0.15206479 0.622277   0.22565818]
# 1009 rude 1 1 [0.20166391 0.5513522  0.24698387]
# 452 hostess 1 1 [0.16143951 0.6502595  0.18830103]
# 1592 waiter 1 1 [0.17338167 0.63573366 0.19088468]
# 584 bartend 1 1 [0.20229957 0.5568175  0.24088296]
# 711 waitress 1 1 [0.17334919 0.6221424  0.20450847]
# 1012 help 1 1 [0.19154179 0.5820153  0.22644293]
# 216 polit 1 1 [0.17366503 0.5991291  0.22720596]
# 1401 bar 1 1 [0.18699458 0.5814581  0.2315474 ]
# 1962 courteou 1 1 [0.21969123 0.5428093  0.2374994 ]
# 2722 member 1 1 [0.18620993 0.5529918  0.2607983 ]
# 368 waitstaff 1 1 [0.16283242 0.6097605  0.22740704]
# 685 attitud 1 1 [0.16738246 0.6350921  0.19752543]
# 1815 reserv 1 1 [0.16259566 0.6288147  0.20858966]
# 2252 tip 1 1 [0.14141501 0.66206527 0.19651969]
# 2529 atmospher 2 2 [0.20298287 0.20418404 0.59283304]
# 579 scene 2 1 [0.24829096 0.38971555 0.3619935 ]
# 2318 place 2 2 [0.23461601 0.28782126 0.47756273]
# 2199 tabl 2 2 [0.28861853 0.3216873  0.38969415]
# 575 outsid 2 2 [0.20492329 0.35154232 0.4435344 ]
# 965 area 2 2 [0.29272994 0.29559195 0.41167808]
# 463 ambianc 2 1 [0.27255857 0.41984934 0.30759218]
# 1675 outdoor 2 2 [0.20294131 0.29616514 0.50089353]
# 1589 romant 2 2 [0.24336214 0.281197   0.47544086]
# 2616 cozi 2 2 [0.24915206 0.34264758 0.4082004 ]
# 457 decor 2 2 [0.2483938  0.35507017 0.39653602]
# 1942 sit 2 2 [0.31199503 0.2087709  0.47923413]
# 2705 wall 2 2 [0.24014834 0.2992698  0.46058193]
# 2643 light 2 2 [0.22777754 0.263664   0.5085584 ]
# 864 window 2 2 [0.33741096 0.2161001  0.44648898]
# 965 area 2 2 [0.29272994 0.29559195 0.41167808]
# 85 ceil 2 2 [0.18231079 0.30119443 0.51649475]
# 161 floor 2 2 [0.27353564 0.21783596 0.50862837]

# %%
emb = model.de_fc.weight.data.cpu().numpy().T
print_top_words(emb, vocab, 50)
print_perp(model)
# Out:
# ---------------Printing the Topics------------------
# chicken sausag scallop tender roll grill roast menu sear eel kobe pineappl filet beef hearti lettuc citru loaf creami brais shrimp salt dumpl duck tofu root nut octopu either homemad greasi oil foie die gener miso kielbasa great dessert egg veget salmon chipotl perfectli rich pepper sichuan peke highlight curri
# n waitress java take even reserv terribl away min without need staff charg attent tell smooth us constantli host bad effici drink order hour inattent sincer problem came mediocr waiter bold patient got spill go bother diet poor embarrass though confirm ruin anoth wo last wrong bill e forgotten kept
# feel chair dark wooden lit paint color tone franchis soar cozi wood place deco atmospher mirror shini midtown tier accent ba mod lamp dim outdoor strike look stylish area silver ceil mismatch weather overhead enclos inspir spaciou carpet band neon chines rear villag bakeri cater rail poster drape vintag environ
# ---------------End of Topics------------------
# The approximated perplexity is:  1.0212110196456305e+25
